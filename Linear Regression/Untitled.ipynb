# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 28C8-D64A
#
#  Directory of C:\Users\ASUS\Downloads
#
# 10-07-2024  20:39    <DIR>          .
# 14-06-2024  02:15    <DIR>          ..
# 10-07-2024  20:39    <DIR>          .ipynb_checkpoints
# 28-05-2024  00:32       948,300,296 Anaconda3-2024.02-1-Windows-x86_64.exe
# 28-05-2024  19:31    <DIR>          archive
# 28-05-2024  19:25            17,093 archive.zip
# 05-05-2024  23:25           150,977 asir1.pdf
# 05-05-2024  23:38           151,022 asir2.pdf
# 04-06-2024  11:29            47,113 Bala MuruganL_InternshalaResume.pdf
# 05-05-2024  23:20           150,810 barath1.pdf
# 05-05-2024  23:32           150,823 barath2.pdf
# 30-05-2024  14:20           552,929 bhp.csv
# 04-05-2024  19:40           992,502 bottom2.pdf
# 04-05-2024  19:42         1,156,804 bottom2_merged.pdf
# 04-05-2024  19:55           992,228 bottom3.pdf
# 04-05-2024  20:08         1,156,621 bottom3_merged (1).pdf
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df4=pd.read_csv('canada_per_capita_income.csv')

# %%
df4
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1999
# 16  2000
# 17  2001
# 18  2002
# 19  2003
# 20  2004
# 21  2005
# 22  2006
# 23  2007
# 24  2008
# 25  2009
# 26  2010
# 27  2011

# %%
df.head(3)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484

# %%
df_x=df['year']
df_x
# Out:
# 0     1970
# 1     1971
# 2     1972
# 3     1973
# 4     1974
# 5     1975
# 6     1976
# 7     1977
# 8     1978
# 9     1979
# 10    1980
# 11    1981
# 12    1982
# 13    1983
# 14    1984
# 15    1985
# 16    1986
# 17    1987
# 18    1988
# 19    1989
# 20    1990
# 21    1991
# 22    1992
# 23    1993
# 24    1994
# 25    1995
# 26    1996
# 27    1997
# 28    1998
# 29    1999
# 30    2000
# 31    2001
# 32    2002
# 33    2003
# 34    2004
# 35    2005
# 36    2006
# 37    2007
# 38    2008
# 39    2009
# 40    2010
# 41    2011
# 42    2012
# 43    2013
# 44    2014
# 45    2015
# 46    2016
# Name: year, dtype: int64

# %%
df_y=df['per capita income (US$)']
df_y
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
plt.scatter(df_x,df_y,color='red',marker='+')
plt.xlabel('years')
plt.ylabel('per capita(US$)')
# Out:
# Text(0, 0.5, 'per capita(US$)')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
p2=reg.predict(df4)
df4['predicted_val']=p2
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df4.to_csv('percapita_pred.csv')

# %%
plt.scatter(df4.year,df4['predicted_val'],color='green',marker='+')
plt.plot(df4.year,df4['predicted_val'])

# %%
df.head(15)
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720

# %%
df3=pd.read_csv('homeprices.csv')
df3
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
reg2=linear_model.LinearRegression()
reg2.fit(df2[['area']],df2.price)
reg2.predict([[2600]])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %%
reg2.predict([[3000]])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
df2=pd.read_csv("predicted.csv")
p=reg2.predict(df2)
p
df2['predicted_val']=p
df2
# Out:
#     area  predicted_val
# 0  80000   1.104363e+07
# 1   9000   1.402705e+06
# 2   8000   1.266918e+06
# 3   2000   4.521918e+05
# 4   5000   8.595548e+05
# 5   3000   5.879795e+05
# 6  12000   1.810068e+06
# 7  30000   4.254247e+06

# %%
df2.to_csv('predicted_op.csv')

# %%
plt.scatter(df2['area'],df2['predicted_val'],color='red',marker='*')
plt.plot(df2['area'],df2['predicted_val'])

# %%
! dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 28C8-D64A
#
#  Directory of C:\Users\ASUS\Downloads
#
# 10-07-2024  21:20    <DIR>          .
# 14-06-2024  02:15    <DIR>          ..
# 10-07-2024  20:39    <DIR>          .ipynb_checkpoints
# 28-05-2024  00:32       948,300,296 Anaconda3-2024.02-1-Windows-x86_64.exe
# 28-05-2024  19:31    <DIR>          archive
# 28-05-2024  19:25            17,093 archive.zip
# 05-05-2024  23:25           150,977 asir1.pdf
# 05-05-2024  23:38           151,022 asir2.pdf
# 04-06-2024  11:29            47,113 Bala MuruganL_InternshalaResume.pdf
# 05-05-2024  23:20           150,810 barath1.pdf
# 05-05-2024  23:32           150,823 barath2.pdf
# 30-05-2024  14:20           552,929 bhp.csv
# 04-05-2024  19:40           992,502 bottom2.pdf
# 04-05-2024  19:42         1,156,804 bottom2_merged.pdf
# 04-05-2024  19:55           992,228 bottom3.pdf
# 04-05-2024  20:08         1,156,621 bottom3_merged (1).pdf
# ...
